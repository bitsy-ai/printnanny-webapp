# %%
import imageio
from print_nanny_webapp.utils.predictor import ThreadLocalPredictor, predict_events_to_dataframe
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
reader = imageio.get_reader('/app/data/-0-0uBnUSnc.mp4')

predictor = ThreadLocalPredictor()


predictions = []
for i, image in enumerate(reader):
    predict_data = predictor.predict(image)
    predict_data['viz'] = predictor.postprocess(image, predict_data)
    data = {'predict_data': predict_data, 'id': i }
    predictions.append(data)
# for i, img in enumerate(reader):
#     print(i)
#     tensor = np.asarray(img)


#predictions.append(predictor.predict(tensor))

predictions
# Out:
# {0: {'name': 'background', 'id': 0}, 1: {'name': 'nozzle', 'id': 1}, 2: {'name': 'adhesion', 'id': 2}, 3: {'name': 'spaghetti', 'id': 3}, 4: {'name': 'print', 'id': 4}, 5: {'name': 'raft', 'id': 5}}
# [{'predict_data': {'detection_boxes': array([[ 4.58236873e-01,  5.90465665e-01,  4.82135594e-01,
#             6.14908457e-01],
#           [ 4.62180912e-01,  5.94738007e-01,  4.88331497e-01,
#             6.17584586e-01],
#           [ 4.63636398e-01,  5.83730519e-01,  4.90082979e-01,
#             6.07899725e-01],
#           [ 4.58018303e-01,  5.77753901e-01,  4.78612661e-01,
#             6.30530238e-01],
#           [ 4.89076316e-01,  5.99146545e-01,  5.19008696e-01,
#             6.23866022e-01],
#           [ 4.95362461e-01,  6.24034107e-01,  5.21809042e-01,
#             6.49602592e-01],
#           [ 5.05582809e-01,  6.56818509e-01,  5.24832249e-01,
#             7.30794311e-01],
#           [ 4.45177108e-01,  5.21813214e-01,  4.76487964e-01,
#             5.45982420e-01],
# ...

# %%
df = predict_events_to_dataframe(predictions)

df
# Out:
#                                        detection_boxes  \
# id
# 0    [[0.45823687, 0.59046566, 0.4821356, 0.6149084...
# 1    [[0.48223186, 0.84138817, 0.6471373, 0.9972691...
# 2    [[0.51865387, 0.45078614, 0.55876267, 0.483172...
# 3    [[0.5182006, 0.45123178, 0.5565435, 0.48219222...
# 4    [[0.5202146, 0.4506033, 0.5598745, 0.4812172],...
# ..                                                 ...
# 278  [[0.54678464, 0.22103597, 0.9956572, 0.6905802...
# 279  [[0.5363299, 0.21297379, 0.99542195, 0.6772625...
# 280  [[0.54395175, 0.21836348, 0.9878001, 0.6879077...
# 281  [[0.5491082, 0.21824461, 0.98798865, 0.6773366...
# 282  [[0.5681636, 0.22477008, 0.99109477, 0.6721862...
#
#                                      detection_classes  \
# id
# 0    [1, 1, 1, 5, 1, 1, 5, 1, 1, 5, 1, 4, 1, 5, 5, ...
# 1    [5, 3, 5, 3, 3, 5, 1, 1, 4, 4, 4, 4, 3, 5, 5, ...
# 2    [1, 5, 5, 5, 4, 5, 5, 1, 5, 5, 1, 4, 1, 5, 1, ...
# 3    [1, 5, 5, 5, 1, 4, 1, 5, 5, 4, 5, 1, 5, 4, 1, ...
# ...
